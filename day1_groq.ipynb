# %% [markdown]
# # DAY 1 our first file , get key and run for the RAG

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "groq"], capture_output=False)

# %%
from groq import Groq

client = Groq(api_key="Your_Grok_Key")

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",  # free, very powerful
    messages=[
        {"role": "user", "content": "What is RAG in 3 lines?"}
    ]
)

print(response.choices[0].message.content)

# %% [markdown]
# # Gives wrong defination so we need to be more specific in our prompts

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": "What is RAG (Retrieval Augmented Generation) in AI? Explain in 3 lines."}
    ]
)
print(response.choices[0].message.content)
