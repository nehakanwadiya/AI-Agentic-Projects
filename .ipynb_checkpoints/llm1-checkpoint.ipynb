# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "groq"], capture_output=False)
# Out:
# CompletedProcess(args=['C:\\Users\\kanwa\\anaconda3\\python.exe', '-m', 'pip', 'install', 'groq'], returncode=0)

# %%
from groq import Groq

client = Groq(api_key="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")

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",  # free, very powerful
    messages=[
        {"role": "user", "content": "What is RAG in 3 lines?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# RAG (Red, Amber, Green) is a status reporting system used to indicate the health of a project or initiative.
# Red typically indicates a project is at risk or behind schedule, Amber indicates caution or potential issues, and Green indicates a project is on track.
# This system provides a simple and visual way to communicate project status and prioritize resources.

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": "What is RAG (Retrieval Augmented Generation) in AI? Explain in 3 lines."}
    ]
)
print(response.choices[0].message.content)
# Out:
# RAG (Retrieval Augmented Generation) is an AI technique that combines retrieval and generation models to produce more accurate and informative responses. It retrieves relevant information from a knowledge base and then uses a generation model to create a response based on that information. This approach helps to improve the accuracy and fluency of generated text, especially for tasks like question-answering and text summarization.

# %%
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
